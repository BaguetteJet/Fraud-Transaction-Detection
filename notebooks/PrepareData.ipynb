# %%
import os
import pandas as pd

# %% [markdown]
# Ensure processed data folder exists

# %%
os.makedirs('../data/processed', exist_ok=True)

# %% [markdown]
# Load raw data

# %%
df_raw = pd.read_csv('../data/raw/credit_data.csv')
df_clean = df_raw.copy()

# %% [markdown]
# Remove duplicates

# %%
df_clean.dropna()

# %% [markdown]
# CONTINUE...
